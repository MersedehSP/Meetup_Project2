# %%
import pandas as pd
import numpy as np

# %%
venue_df = pd.read_csv('events_venue.csv')
venue_df
# Out:
#                                              event_link event_state  \
# 0     https://www.meetup.com/washingtoncrossingstate...          nj
# 1        https://www.meetup.com/NJ-Dug/events/275376752          nj
# 2     https://www.meetup.com/S-M-A-R-T-Recovery-at-L...          NJ
# 3     https://www.meetup.com/Lifebacks-Helping-Famil...          NJ
# 4     https://www.meetup.com/meetup-group-uLdxSObt/e...          PA
# ...                                                 ...         ...
# 1785  https://www.meetup.com/S-M-A-R-T-Recovery-at-L...          NJ
# 1786  https://www.meetup.com/Lifebacks-Helping-Famil...          NJ
# 1787  https://www.meetup.com/BucksMont-Squires-of-So...          PA
# 1788  https://www.meetup.com/Danville-Ukulele-Meetup...          PA
# 1789  https://www.meetup.com/Mountain-Top-Performanc...          PA
#
#              event_city                            event_street  \
# 0            Titusville  355 Washington Crossing Pennington Rd.
# ...

# %%
cols = ['event_state', 'event_city', 'event_street', 'Google_Map_Link']
venue_df[:].replace(' ', np.NaN).head(50)
# Out:
#                                            event_link event_state  \
# 0   https://www.meetup.com/washingtoncrossingstate...          nj
# 1      https://www.meetup.com/NJ-Dug/events/275376752          nj
# 2   https://www.meetup.com/S-M-A-R-T-Recovery-at-L...          NJ
# 3   https://www.meetup.com/Lifebacks-Helping-Famil...          NJ
# 4   https://www.meetup.com/meetup-group-uLdxSObt/e...          PA
# 5   https://www.meetup.com/Princeton-Yoga/events/2...          NJ
# 6   https://www.meetup.com/PrincetonYogaCenter/eve...          NJ
# 7   https://www.meetup.com/Morrisville-Playing-Pic...          PA
# 8   https://www.meetup.com/Senior-Sunrise-Walkers/...          PA
# 9   https://www.meetup.com/Yardley-Rec-Board/event...          PA
# 10  https://www.meetup.com/League-of-Extraordinary...          NJ
# 11  https://www.meetup.com/Hamilton-Creative-Non-f...          NJ
# 12  https://www.meetup.com/Lawrence-Writers-Meetup...          NJ
# ...

# %%
venue_df['event_state']= venue_df['event_state'].str.upper()
venue_df
# Out:
#                                              event_link event_state  \
# 0     https://www.meetup.com/washingtoncrossingstate...          NJ
# 1        https://www.meetup.com/NJ-Dug/events/275376752          NJ
# 2     https://www.meetup.com/S-M-A-R-T-Recovery-at-L...          NJ
# 3     https://www.meetup.com/Lifebacks-Helping-Famil...          NJ
# 4     https://www.meetup.com/meetup-group-uLdxSObt/e...          PA
# ...                                                 ...         ...
# 1785  https://www.meetup.com/S-M-A-R-T-Recovery-at-L...          NJ
# 1786  https://www.meetup.com/Lifebacks-Helping-Famil...          NJ
# 1787  https://www.meetup.com/BucksMont-Squires-of-So...          PA
# 1788  https://www.meetup.com/Danville-Ukulele-Meetup...          PA
# 1789  https://www.meetup.com/Mountain-Top-Performanc...          PA
#
#              event_city                            event_street  \
# 0            Titusville  355 Washington Crossing Pennington Rd.
# ...

# %%
venue_df.to_csv('New_Final_data.csv', index=False)
