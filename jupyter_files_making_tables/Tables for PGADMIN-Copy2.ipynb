# %%
import pandas as pd
import numpy as np

# %%
# Save path to data set in a variable
data_file_1 = "complete_events_lat_lng.csv"

# %%
# Use Pandas to read data:
event_df = pd.read_csv(data_file_1)

# %%
#gives you the top 5 rows of the file
event_df.head(500)
# Out:
#     state        city                                         event_name  \
# 0      NJ     Trenton                   THURSDAY AFTERNOON AEROBIC HIKE
# 1      NJ     Trenton                         Fly-In at Ellisdale Fields
# 2      NJ     Trenton                         SMART RECOVERY at LifeBack
# 3      NJ     Trenton  Lifeback's Helping Families Affected By Addiction
# 4      NJ     Trenton                          Flying Solo Support Group
# ..    ...         ...                                                ...
# 495    NJ  Union City               Urban Athletics: Ride to Fort Totten
# 496    NJ  Union City  Hudson Walkway Loop/Reese Park Social Distanci...
# 497    NJ  Union City  Grand Central Social Distancing Private Histor...
# 498    NJ  Union City                         SCUBA Discovery Experience
# 499    NJ  Union City                                Nitrox Diver Course
#
#                                             group_name  attendees      lat  \
# 0           Washington Crossing Park Association of NJ          8  40.2236
# 1                                  NJ Drone User Group          1  40.2236
# 2                      S.M.A.R.T. Recovery at LifeBack          1  40.2236
# 3    Lifeback's Helping Families Affected By Addiction          1  40.2236
# 4                            Flying Solo Support Group          1  40.2236
# ..                                                 ...        ...      ...
# 495    NYC Chill Hiking, Camping, and Other Activities         11  40.7674
# 496   New York Hikes, Happy Hours & Outdoor Adventures          1  40.7674
# 497                      SINGLES TRAVEL AND ADVENTURE!          1  40.7674
# 498                             NJ  Scuba Meetup Group          5  40.7674
# 499                              NJ Warren Scuba Group          1  40.7674
#
#          lng  population                                   venue_event_link  \
# 0   -74.7641      290716  https://www.meetup.com/washingtoncrossingstate...
# 1   -74.7641      290716     https://www.meetup.com/NJ-Dug/events/275376752
# 2   -74.7641      290716  https://www.meetup.com/S-M-A-R-T-Recovery-at-L...
# 3   -74.7641      290716  https://www.meetup.com/Lifebacks-Helping-Famil...
# 4   -74.7641      290716  https://www.meetup.com/meetup-group-uLdxSObt/e...
# ..       ...         ...                                                ...
# 495 -74.0323       67982  https://www.meetup.com/NYC-Chill-Hiking-Campin...
# 496 -74.0323       67982  https://www.meetup.com/New-York-Hikes-Happy-Ho...
# 497 -74.0323       67982  https://www.meetup.com/SINGLES-TRAVEL-AND-ADVE...
# 498 -74.0323       67982   https://www.meetup.com/scuba-nj/events/275651699
# 499 -74.0323       67982  https://www.meetup.com/Scuba-Divers-Travel-Net...
#
#     event_state         event_city  \
# 0            NJ         Titusville
# 1            NJ      Chesterfield
# 2            NJ  Lawrence Township
# 3            NJ  Lawrence Township
# 4            PA            Newtown
# ..          ...                ...
# 495          NY           New York
# 496          NY           New York
# 497          NY           New York
# 498          NJ               Lodi
# 499          NJ               Lodi
#
#                                           event_street  \
# 0               355 Washington Crossing Pennington Rd.
# 1                                   410 Ellisdale Road
# 2                                        4 Princess Rd
# 3                                        4 Princess Rd
# 4                                25 N. Chancellor St.
# ..                                                 ...
# 495                            27 W 24th St Suite 800B
# 496  Your Guide will meet you when you get out from...
# 497    90 West 42nd Street (Across from Grand Central)
# 498                                 460 Passaic Avenue
# 499                                 460 Passaic Avenue
#
#                                        Google_Map_Link  event_lat  event_lng  \
# 0    https://www.google.com/maps/search/?api=1&quer...  40.309223 -74.846391
# 1    https://www.google.com/maps/search/?api=1&quer...  40.140632 -74.629200
# 2    https://www.google.com/maps/search/?api=1&quer...  40.295540 -74.720370
# 3    https://www.google.com/maps/search/?api=1&quer...  40.295540 -74.720370
# 4    https://www.google.com/maps/search/?api=1&quer...  40.232371 -74.932537
# ..                                                 ...        ...        ...
# 495  https://www.google.com/maps/search/?api=1&quer...  42.735393 -73.713230
# 496  https://www.google.com/maps/search/?api=1&quer...  40.709686 -74.011674
# 497  https://www.google.com/maps/search/?api=1&quer...  40.754663 -73.983167
# 498  https://www.google.com/maps/search/?api=1&quer...  40.858938 -74.111060
# 499  https://www.google.com/maps/search/?api=1&quer...  40.858938 -74.111060
#
#                                                address
# 0    "355 Washington Crossing Pennington Rd.,Titusv...
# 1                "410 Ellisdale Road,Chesterfield ,NJ"
# 2                 "4 Princess Rd,Lawrence Township,NJ"
# 3                 "4 Princess Rd,Lawrence Township,NJ"
# 4                   "25 N. Chancellor St. ,Newtown,PA"
# ..                                                 ...
# 495              "27 W 24th St Suite 800B,New York,NY"
# 496  "Your Guide will meet you when you get out fro...
# 497  "90 West 42nd Street (Across from Grand Centra...
# 498                       "460 Passaic Avenue,Lodi,NJ"
# 499                       "460 Passaic Avenue,Lodi,NJ"
#
# [500 rows x 16 columns]

# %%
event_df = event_df.loc[event_df['state'] == event_df["event_state"]]
event_df
# Out:
#      state          city                                         event_name  \
# 0       NJ       Trenton                   THURSDAY AFTERNOON AEROBIC HIKE
# 1       NJ       Trenton                         Fly-In at Ellisdale Fields
# 2       NJ       Trenton                         SMART RECOVERY at LifeBack
# 3       NJ       Trenton  Lifeback's Helping Families Affected By Addiction
# 5       NJ       Trenton    New! Online Zoom Yoga classes at Princeton Yoga
# ...    ...           ...                                                ...
# 1374    PA  Williamsport                             Inquiry into Awakening
# 1376    PA     Levittown                          Flying Solo Support Group
# 1379    PA     Levittown                            Let's meet up and sing!
# 1380    PA    Bloomsburg                                   Open Ukulele Jam
# 1381    PA  Wilkes Barre                                 Country Heat LIVE!
#
#                                              group_name  attendees      lat  \
# 0            Washington Crossing Park Association of NJ          8  40.2236
# 1                                   NJ Drone User Group          1  40.2236
# 2                       S.M.A.R.T. Recovery at LifeBack          1  40.2236
# 3     Lifeback's Helping Families Affected By Addiction          1  40.2236
# 5                                        Princeton Yoga          1  40.2236
# ...                                                 ...        ...      ...
# 1374          Night Sky Sangha "Inquiry into Awakening"          1  41.2398
# 1376                          Flying Solo Support Group          1  40.1537
# 1379                          BucksMont Squires of Song          1  40.1537
# 1380                            Danville Ukulele Meetup          1  41.0027
# 1381   NEPA Performance Workouts for All Fitness Levels          1  41.2468
#
#           lng  population                                   venue_event_link  \
# 0    -74.7641      290716  https://www.meetup.com/washingtoncrossingstate...
# 1    -74.7641      290716     https://www.meetup.com/NJ-Dug/events/275376752
# 2    -74.7641      290716  https://www.meetup.com/S-M-A-R-T-Recovery-at-L...
# 3    -74.7641      290716  https://www.meetup.com/Lifebacks-Helping-Famil...
# 5    -74.7641      290716  https://www.meetup.com/Princeton-Yoga/events/2...
# ...       ...         ...                                                ...
# 1374 -77.0371       53861  https://www.meetup.com/Night-Sky-Sangha/events...
# 1376 -74.8530       51726  https://www.meetup.com/meetup-group-uLdxSObt/e...
# 1379 -74.8530       51726  https://www.meetup.com/BucksMont-Squires-of-So...
# 1380 -76.4561       49840  https://www.meetup.com/Danville-Ukulele-Meetup...
# 1381 -75.8759       40766  https://www.meetup.com/Mountain-Top-Performanc...
#
#      event_state         event_city                            event_street  \
# 0             NJ         Titusville  355 Washington Crossing Pennington Rd.
# 1             NJ      Chesterfield                       410 Ellisdale Road
# 2             NJ  Lawrence Township                           4 Princess Rd
# 3             NJ  Lawrence Township                           4 Princess Rd
# 5             NJ           Skillman         88 Orchard Road, Princeton Area
# ...          ...                ...                                     ...
# 1374          PA       Pennsylvania                                     Now
# 1376          PA            Newtown                   25 N. Chancellor St.
# 1379          PA          Langhorne                        301 E. Maple Ave
# 1380          PA           Danville                             407 Pine St
# 1381          PA           Kingston                          500 3rd Avenue
#
#                                         Google_Map_Link  event_lat  event_lng  \
# 0     https://www.google.com/maps/search/?api=1&quer...  40.309223 -74.846391
# 1     https://www.google.com/maps/search/?api=1&quer...  40.140632 -74.629200
# 2     https://www.google.com/maps/search/?api=1&quer...  40.295540 -74.720370
# 3     https://www.google.com/maps/search/?api=1&quer...  40.295540 -74.720370
# 5     https://www.google.com/maps/search/?api=1&quer...  40.416608 -74.659244
# ...                                                 ...        ...        ...
# 1374  https://www.google.com/maps/search/?api=1&quer...  41.571348 -75.254823
# 1376  https://www.google.com/maps/search/?api=1&quer...  40.232371 -74.932537
# 1379  https://www.google.com/maps/search/?api=1&quer...  40.203881 -74.897680
# 1380  https://www.google.com/maps/search/?api=1&quer...  40.966481 -76.613147
# 1381  https://www.google.com/maps/search/?api=1&quer...  41.261748 -75.896863
#
#                                                 address
# 0     "355 Washington Crossing Pennington Rd.,Titusv...
# 1                 "410 Ellisdale Road,Chesterfield ,NJ"
# 2                  "4 Princess Rd,Lawrence Township,NJ"
# 3                  "4 Princess Rd,Lawrence Township,NJ"
# 5         "88 Orchard Road, Princeton Area,Skillman,NJ"
# ...                                                 ...
# 1374                              "Now,Pennsylvania,PA"
# 1376                 "25 N. Chancellor St. ,Newtown,PA"
# 1379                    "301 E. Maple Ave,Langhorne,PA"
# 1380                          "407 Pine St,Danville,PA"
# 1381                       "500 3rd Avenue,Kingston,PA"
#
# [607 rows x 16 columns]

# %%
event_df['event_city'].head()
#Find all instances of a value and replace
#bottleking_df["price"] = bottleking_df["price"].str.replace("$", "").astype(float)
# Out:
# 0           Titusville
# 1        Chesterfield
# 2    Lawrence Township
# 3    Lawrence Township
# 5             Skillman
# Name: event_city, dtype: object

# %%
test1 = event_df.groupby([ 'state', 'city', 'event_city', 'lat', 'lng', 'population']).size().reset_index().rename(columns = {0:'count'})
test2 = test1.reset_index()
test2
test3 = test2.rename(columns={"index": 'region_id'})
test3 = test3.drop(["count"], axis= "columns")
test3.head(443)
# Out:
#      region_id state           city     event_city      lat      lng  \
# 0            0    NJ  Atlantic City   Somers Point  39.3797 -74.4527
# 1            1    NJ        Bayonne        Bayonne  40.6661 -74.1141
# 2            2    NJ        Bayonne       Columbia  40.6661 -74.1141
# 3            3    NJ        Bayonne        Hoboken  40.6661 -74.1141
# 4            4    NJ        Bayonne    Jersey City  40.6661 -74.1141
# ..         ...   ...            ...            ...      ...      ...
# 344        344    PA        Reading     Wyomissing  40.3400 -75.9267
# 345        345    PA  State College  State College  40.7909 -77.8568
# 346        346    PA   Wilkes Barre       Kingston  41.2468 -75.8759
# 347        347    PA   Williamsport   Pennsylvania  41.2398 -77.0371
# 348        348    PA           York           York  39.9651 -76.7315
#
#      population
# 0        237054
# 1         64897
# 2         64897
# 3         64897
# 4         64897
# ..          ...
# 344      267155
# 345       87723
# 346       40766
# 347       53861
# 348      233184
#
# [349 rows x 7 columns]

# %%
new_df = pd.merge(event_df, test3, how='left', left_on=[ 'state', 'city', 'event_city', 'lat', 'lng', 'population' ], right_on = [ 'state', 'city', 'event_city', 'lat', 'lng', 'population'])
new_df
new_df = new_df.drop([ 'state', 'city', 'lat', 'lng', 'population'] , axis ="columns")
new_df['region_id'] = new_df['region_id'].astype(int)
new_df
# Out:
#                                             event_name  \
# 0                     THURSDAY AFTERNOON AEROBIC HIKE
# 1                           Fly-In at Ellisdale Fields
# 2                           SMART RECOVERY at LifeBack
# 3    Lifeback's Helping Families Affected By Addiction
# 4      New! Online Zoom Yoga classes at Princeton Yoga
# ..                                                 ...
# 602                             Inquiry into Awakening
# 603                          Flying Solo Support Group
# 604                            Let's meet up and sing!
# 605                                   Open Ukulele Jam
# 606                                 Country Heat LIVE!
#
#                                             group_name  attendees  \
# 0           Washington Crossing Park Association of NJ          8
# 1                                  NJ Drone User Group          1
# 2                      S.M.A.R.T. Recovery at LifeBack          1
# 3    Lifeback's Helping Families Affected By Addiction          1
# 4                                       Princeton Yoga          1
# ..                                                 ...        ...
# 602          Night Sky Sangha "Inquiry into Awakening"          1
# 603                          Flying Solo Support Group          1
# 604                          BucksMont Squires of Song          1
# 605                            Danville Ukulele Meetup          1
# 606   NEPA Performance Workouts for All Fitness Levels          1
#
#                                       venue_event_link event_state  \
# 0    https://www.meetup.com/washingtoncrossingstate...          NJ
# 1       https://www.meetup.com/NJ-Dug/events/275376752          NJ
# 2    https://www.meetup.com/S-M-A-R-T-Recovery-at-L...          NJ
# 3    https://www.meetup.com/Lifebacks-Helping-Famil...          NJ
# 4    https://www.meetup.com/Princeton-Yoga/events/2...          NJ
# ..                                                 ...         ...
# 602  https://www.meetup.com/Night-Sky-Sangha/events...          PA
# 603  https://www.meetup.com/meetup-group-uLdxSObt/e...          PA
# 604  https://www.meetup.com/BucksMont-Squires-of-So...          PA
# 605  https://www.meetup.com/Danville-Ukulele-Meetup...          PA
# 606  https://www.meetup.com/Mountain-Top-Performanc...          PA
#
#             event_city                            event_street  \
# 0           Titusville  355 Washington Crossing Pennington Rd.
# 1        Chesterfield                       410 Ellisdale Road
# 2    Lawrence Township                           4 Princess Rd
# 3    Lawrence Township                           4 Princess Rd
# 4             Skillman         88 Orchard Road, Princeton Area
# ..                 ...                                     ...
# 602       Pennsylvania                                     Now
# 603            Newtown                   25 N. Chancellor St.
# 604          Langhorne                        301 E. Maple Ave
# 605           Danville                             407 Pine St
# 606           Kingston                          500 3rd Avenue
#
#                                        Google_Map_Link  event_lat  event_lng  \
# 0    https://www.google.com/maps/search/?api=1&quer...  40.309223 -74.846391
# 1    https://www.google.com/maps/search/?api=1&quer...  40.140632 -74.629200
# 2    https://www.google.com/maps/search/?api=1&quer...  40.295540 -74.720370
# 3    https://www.google.com/maps/search/?api=1&quer...  40.295540 -74.720370
# 4    https://www.google.com/maps/search/?api=1&quer...  40.416608 -74.659244
# ..                                                 ...        ...        ...
# 602  https://www.google.com/maps/search/?api=1&quer...  41.571348 -75.254823
# 603  https://www.google.com/maps/search/?api=1&quer...  40.232371 -74.932537
# 604  https://www.google.com/maps/search/?api=1&quer...  40.203881 -74.897680
# 605  https://www.google.com/maps/search/?api=1&quer...  40.966481 -76.613147
# 606  https://www.google.com/maps/search/?api=1&quer...  41.261748 -75.896863
#
#                                                address  region_id
# 0    "355 Washington Crossing Pennington Rd.,Titusv...        226
# 1                "410 Ellisdale Road,Chesterfield ,NJ"        219
# 2                 "4 Princess Rd,Lawrence Township,NJ"        221
# 3                 "4 Princess Rd,Lawrence Township,NJ"        221
# 4        "88 Orchard Road, Princeton Area,Skillman,NJ"        225
# ..                                                 ...        ...
# 602                              "Now,Pennsylvania,PA"        347
# 603                 "25 N. Chancellor St. ,Newtown,PA"        339
# 604                    "301 E. Maple Ave,Langhorne,PA"        338
# 605                          "407 Pine St,Danville,PA"        329
# 606                       "500 3rd Avenue,Kingston,PA"        346
#
# [607 rows x 12 columns]

# %%
test3 = test3.drop(["event_city"], axis = 'columns')
test3
# Out:
#      region_id state           city      lat      lng  population
# 0            0    NJ  Atlantic City  39.3797 -74.4527      237054
# 1            1    NJ        Bayonne  40.6661 -74.1141       64897
# 2            2    NJ        Bayonne  40.6661 -74.1141       64897
# 3            3    NJ        Bayonne  40.6661 -74.1141       64897
# 4            4    NJ        Bayonne  40.6661 -74.1141       64897
# ..         ...   ...            ...      ...      ...         ...
# 344        344    PA        Reading  40.3400 -75.9267      267155
# 345        345    PA  State College  40.7909 -77.8568       87723
# 346        346    PA   Wilkes Barre  41.2468 -75.8759       40766
# 347        347    PA   Williamsport  41.2398 -77.0371       53861
# 348        348    PA           York  39.9651 -76.7315      233184
#
# [349 rows x 6 columns]

# %%
test3.to_csv('region.csv', encoding='utf-8', index=False)

# %%
new_df.to_csv('events.csv', encoding='utf-8', index=False)

# %%
import re

# %%
def strip_character(dataCol):
    r = re.compile(r'[^a-zA-Z !@#$%&*_+-=|\:";<>,./()[\]{}\']')
    return r.sub('', dataCol)

datafile="events.csv"
datafile_df=pd.read_csv(datafile)
pd.set_option("display.max_row", None, "display.max_columns", None)
datafile_df["event_name"] = datafile_df["event_name"].apply(strip_character)
datafile_df["group_name"] = datafile_df["group_name"].apply(strip_character)
datafile_df["venue_event_link"] = datafile_df["venue_event_link"].apply(strip_character)
datafile_df["Google_Map_Link"] = datafile_df["Google_Map_Link"].apply(strip_character)
datafile_df["event_street"] = datafile_df["event_street"].apply(strip_character)
datafile_df["address"] = datafile_df["address"].str.strip(';"')
#datafile_df = datafile_df.rename(columns={'Unnamed:':'id'})
#datafile_df = datafile_df.drop(['Unnamed'])
datafile_df.to_csv("events.csv",index=False)
datafile_df.head()
# Out:
#                                           event_name  \
# 0                   THURSDAY AFTERNOON AEROBIC HIKE
# 1                         Fly-In at Ellisdale Fields
# 2                         SMART RECOVERY at LifeBack
# 3  Lifeback's Helping Families Affected By Addiction
# 4    New! Online Zoom Yoga classes at Princeton Yoga
#
#                                           group_name  attendees  \
# 0         Washington Crossing Park Association of NJ          8
# 1                                NJ Drone User Group          1
# 2                    S.M.A.R.T. Recovery at LifeBack          1
# 3  Lifeback's Helping Families Affected By Addiction          1
# 4                                     Princeton Yoga          1
#
#                                     venue_event_link event_state  \
# 0  https://www.meetup.com/washingtoncrossingstate...          NJ
# 1     https://www.meetup.com/NJ-Dug/events/275376752          NJ
# 2  https://www.meetup.com/S-M-A-R-T-Recovery-at-L...          NJ
# 3  https://www.meetup.com/Lifebacks-Helping-Famil...          NJ
# 4  https://www.meetup.com/Princeton-Yoga/events/2...          NJ
#
#           event_city                            event_street  \
# 0         Titusville  355 Washington Crossing Pennington Rd.
# 1      Chesterfield                       410 Ellisdale Road
# 2  Lawrence Township                           4 Princess Rd
# 3  Lawrence Township                           4 Princess Rd
# 4           Skillman         88 Orchard Road, Princeton Area
#
#                                      Google_Map_Link  event_lat  event_lng  \
# 0  https://www.google.com/maps/search/api=1&query...  40.309223 -74.846391
# 1  https://www.google.com/maps/search/api=1&query...  40.140632 -74.629200
# 2  https://www.google.com/maps/search/api=1&query...  40.295540 -74.720370
# 3  https://www.google.com/maps/search/api=1&query...  40.295540 -74.720370
# 4  https://www.google.com/maps/search/api=1&query...  40.416608 -74.659244
#
#                                              address  region_id
# 0  355 Washington Crossing Pennington Rd.,Titusvi...        226
# 1                410 Ellisdale Road,Chesterfield ,NJ        219
# 2                 4 Princess Rd,Lawrence Township,NJ        221
# 3                 4 Princess Rd,Lawrence Township,NJ        221
# 4        88 Orchard Road, Princeton Area,Skillman,NJ        225
